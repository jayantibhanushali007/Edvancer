# %% [markdown]
# # Downloading files with links

# %%
# from command line : 
# !wget url_to_the_file 
# sometimes this might fail due to various reasons :
# link is stale , or requires login for downloads [you get "Forbidden .." error]
# to install wget utility on windows : https://builtvisible.com/download-your-website-with-wget/
# to install wget utility on mac : run this on terminal=> brew install wget
# [install homebrew from here if you havent already : https://brew.sh]
# url given here in the example might get stale , just replace with link to some other file on the web

# !wget https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2019-financial-year-provisional/Download-data/annual-enterprise-survey-2019-financial-year-provisional-csv.csv
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# using package wget
# !pip install wget

import wget
url = 'https://www.python.org/static/img/python-logo.png' 
wget.download(url, './python_icon.png') # download(source, destination)
# Out:
# 100% [..............................................................................] 10102 / 10102
# './python_icon.png'

# %%
# using package wget
# !pip install wget

import wget
url = 'https://www.slideteam.net/media/catalog/product/cache/1280x720/d/i/difference_between_ai_vs_ml_vs_dl_ppt_powerpoint_presentation_ideas_graphics_slide01.jpg' 
wget.download(url, './AI-ML-DL.jpg') # download(source, destination)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-ed65a50d45d7> in <module>
#       4 import wget
#       5 url = 'https://www.slideteam.net/media/catalog/product/cache/1280x720/d/i/difference_between_ai_vs_ml_vs_dl_ppt_powerpoint_presentation_ideas_graphics_slide01.jpg'
# ----> 6 wget.download(url, './AI-ML-DL.jpg') # download(source, destination)
#
# ~\Anaconda3\lib\site-packages\wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
# ...

# %% [markdown]
# # Gathering data from page source : text , tables , links etc

# %% [markdown]
# ### Text

# %%
news_article = "https://www.bbc.com/news/world-europe-56465393"

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# p paragraph
# a links
# tr : table rows
# td : table data
# for a comprehensive list of html tags : https://www.w3schools.com/tags/tag_comment.asp

mydata=urlopen(news_article).read()

# %%
mydata
# Out:
# b'<!DOCTYPE html><html lang="en-GB" class="no-js"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><title data-rh="true">Icelandic volcano erupts near Reykjavik - BBC News</title><meta data-rh="true" name="description" content="Meteorologists say the last known eruption in the area was about 800 years ago."/><meta data-rh="true" name="theme-color" content="#FFFFFF"/><meta data-rh="true" property="article:author" content="https://www.facebook.com/bbcnews"/><meta data-rh="true" property="fb:admins" content="100004154058350"/><meta data-rh="true" property="fb:app_id" content="1609039196070050"/><meta data-rh="true" property="fb:pages" content="1143803202301544,317278538359186,1392506827668140,742734325867560,185246968166196,156060587793370,137920769558355,193435954068976,21263239760,156400551056385,929399697073756,154344434967,228735667216,80758950658,260212261199,294662213128,1086451581439054,283348121682053,295830058648,23993138954541
# ...

# %%
soup = BeautifulSoup(mydata,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
p_tags=soup.find_all('p')

# %%
p_tags
# Out:
# [<p class="ssrcss-1q0x1qg-Paragraph eq5iqo00">This video can not be played</p>,
#  <p class="ssrcss-1q0x1qg-Paragraph eq5iqo00">Aerial footage shows lava  flowing from the volcano south-west of Reykjavik in Iceland</p>,
#  <p class="ssrcss-1q0x1qg-Paragraph eq5iqo00"><b class="ssrcss-hmf8ql-BoldText e5tfeyi3">A volcano has erupted south-west of Iceland's capital Reykjavik, the country's meteorological office says.</b></p>,
#  <p class="ssrcss-1q0x1qg-Paragraph eq5iqo00">It says <a class="ssrcss-k17ofw-InlineLink e1no5rhv0" href="https://vedur.is/um-vi/frettir/skjalfti-m57-a-reykjanesi">the fissure is about 500-700 metres long (1,640-2,300ft) at Fagradalsfjall</a> on Reykjanes peninsula. The last eruption there was some 800 years ago.</p>,
#  <p class="ssrcss-1q0x1qg-Paragraph eq5iqo00">Iceland has recorded more than 40,000 earthquakes in the past three weeks.</p>,
# ...

# %%
for tag in p_tags:
    print(tag.text)
# Out:
# This video can not be played
# Aerial footage shows lava  flowing from the volcano south-west of Reykjavik in Iceland
# A volcano has erupted south-west of Iceland's capital Reykjavik, the country's meteorological office says.
# It says the fissure is about 500-700 metres long (1,640-2,300ft) at Fagradalsfjall on Reykjanes peninsula. The last eruption there was some 800 years ago.
# Iceland has recorded more than 40,000 earthquakes in the past three weeks.
# In 2010 the eruption of another volcano at Eyjafjallajokull brought air traffic to a halt across Europe.
# However, the eruption of Fagradalsfjall is not expected to spew out much ash, so aviation should not suffer disruption.
# The Icelandic Meteorological Office says the eruption of Fagradalsfjall began at about 20:45 GMT on Friday, and was later confirmed via webcams and satellite images.
# A coastguard helicopter was sent to survey the area, about 30km (19 miles) from Reykjavik.
# ...

# %% [markdown]
# ### Links

# %%
a_tags=soup.find_all('a')

# %%
for tag in a_tags:
    link=tag.get('href')
    print(link)
    
# you can filter out links with any criterion . 
# e.g. keep only those links which begin with "https:"
# Out:
# https://www.bbc.com
# #main-heading
# https://www.bbc.co.uk/accessibility/
# https://account.bbc.com/account?lang=en-GB&ptrt=https://www.bbc.com/news/world-europe-56465393
# https://www.bbc.com
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.com/reel
# https://www.bbc.com/worklife
# https://www.bbc.com/travel
# https://www.bbc.com/future
# #chameleon-global-navigation-more-menu
# #chameleon-global-navigation-more-menu
# https://www.bbc.co.uk/search?d=NEWS_GNL
# https://www.bbc.com
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.com/reel
# https://www.bbc.com/worklife
# https://www.bbc.com/travel
# https://www.bbc.com/future
# https://www.bbc.com/culture
# https://www.bbc.com/culture/music
# https://www.bbc.co.uk/schedules/p00fzl9m
# https://www.bbc.com/weather
# https://www.bbc.co.uk/sounds
# #more-menu-button
# /news
# #product-navigation-menu
# /news
# /news/world-60525350
# /news/coronavirus
# /news/science-environment-56837908
# ...

# %% [markdown]
# ### Tables

# %%
url="https://groww.in/stocks/adani-enterprises-ltd"

# %%
mydata=urlopen(url).read()

# %%
mydata
# Out:
# b'<!DOCTYPE html><html lang="en" data-theme="light"><head><meta charSet="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, user-scalable=no" /><link rel="icon" href="/favicon-32x32-groww.ico" /><title>Adani Enterprises Share Price Today - Adani Enterprises Ltd Stock Price Live NSE/BSE</title><meta name="description" content="Adani Enterprises Share Price - Get Adani Enterprises Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,\n    company profile, annual report, quarterly results, profit and loss" /><meta name="robots" content="index" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:image" content="https://groww.in/logo-groww270.png" /><meta name="twitter:description" content="Adani Enterprises Share Price - Get Adani Enterprises Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,\n  
# ...

# %%
soup = BeautifulSoup(mydata,'lxml')

# %%
tables=soup.find_all('table')

# %%
tables
# Out:
# [<table class="tb10Table col l12 ft785Table"><tbody class=""><tr class="col l6 ft785RightSpace" style="border-bottom:none"><td class="ft785Head left-align fs14 clrSubText" colspan="1" rowspan="1" style="padding-left:0px;padding-top:10px;padding-bottom:10px" width="100%">Market Cap</td><td class="ft785Value right-align fs16 clrText fw500" colspan="1" rowspan="1" style="padding-right:0px;padding-top:10px;padding-bottom:10px" width="100%">₹2,75,852Cr</td></tr><tr class="col l6 ft785LeftSpace" style="border-bottom:none"><td class="ft785Head left-align fs14 clrSubText" colspan="1" rowspan="1" style="padding-left:0px;padding-top:10px;padding-bottom:10px" width="100%">ROE</td><td class="ft785Value right-align fs16 clrText fw500" colspan="1" rowspan="1" style="padding-right:0px;padding-top:10px;padding-bottom:10px" width="100%">8.94%</td></tr><tr class="col l6 ft785RightSpace" style="border-bottom:none"><td class="ft785Head left-align fs14 clrSubText" colspan="1" rowspan="1" style="padding-l
# ...

# %%
mytable=tables[4]

for rows in mytable.findAll('tr'):
    data=rows.findAll('td')
    print_data=[]
    for d in data:
        print_data.append(d.text)
    print(print_data)
# Out:
# []
# ['Indiamart Intermesh', '', 'NA(0.00%)', '62.57', '']
# ['MMTC', '', 'NA(0.00%)', '3.18', '']
# ['Somany Home Innovation', '', 'NA(0.00%)', '74.79', '']
# ['Shree Global Tradefin', '', 'NA(0.00%)', '76.20', '']

# %%
mytable=tables[0]

mytable.findAll('tr')
# Out:
# [<tr class="col l6 ft785RightSpace" style="border-bottom:none"><td class="ft785Head left-align fs14 clrSubText" colspan="1" rowspan="1" style="padding-left:0px;padding-top:10px;padding-bottom:10px" width="100%">Market Cap</td><td class="ft785Value right-align fs16 clrText fw500" colspan="1" rowspan="1" style="padding-right:0px;padding-top:10px;padding-bottom:10px" width="100%">₹2,74,769Cr</td></tr>,
#  <tr class="col l6 ft785LeftSpace" style="border-bottom:none"><td class="ft785Head left-align fs14 clrSubText" colspan="1" rowspan="1" style="padding-left:0px;padding-top:10px;padding-bottom:10px" width="100%">ROE</td><td class="ft785Value right-align fs16 clrText fw500" colspan="1" rowspan="1" style="padding-right:0px;padding-top:10px;padding-bottom:10px" width="100%">8.94%</td></tr>,
# ...

# %%
for rows in mytable.findAll('tr'):
    data=rows.findAll('td')
    print_data=[]
    for d in data:
        print_data.append(d.text)
    print(print_data)
# Out:
# ['Market Cap', '₹2,74,769Cr']
# ['ROE', '8.94%']
# ['P/E Ratio(TTM)', '110.70']
# ['EPS(TTM)', '21.77']
# ['P/B Ratio', '8.31']
# ['Dividend Yield', '0.05%']
# ['Industry P/E', 'NA']
# ['Book Value', '289.92']
# ['Debt to Equity', '1.61']
# ['Face Value', '1']

# %% [markdown]
# ### Explore Further

# %%
# for simulating browsing with code [ submitting forms  , comments , msgs ect ]
# mechanize : https://mechanize.readthedocs.io/en/latest/
# selenium : https://selenium-python.readthedocs.io
