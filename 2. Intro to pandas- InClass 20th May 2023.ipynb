# %% [markdown]
# In this module we will start with the fabled python package named pandas which has become defacto tool for handling datasets in python. In this videos we will look at following aspects of pandas
#
# 1. Manually creating data frames
# 2. Reading data from external file
# 3. peripheral summary of the data
# 4. subsetting on the basis of rownumber , colnumber
# 5. subsetting on the basis of condition
# 6. subsetting on the basis of column names

# %% [markdown]
# lets import the package first and then we will create dataframes manually

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# there are two ways to create dataframes from list of values as columns . Lets first create some lists values

# %%
age=np.random.randint(low=16,high=80,size=[20,])

city=np.random.choice(['Mumbai','Delhi','Chennai','Kolkata'],20)

default=np.random.choice([0,1],20)

# %%
print(age)
print(city)
print(default)
# Out:
# [53 37 78 43 54 61 64 71 24 54 76 53 31 31 58 49 71 18 62 59]
# ['Delhi' 'Mumbai' 'Mumbai' 'Kolkata' 'Mumbai' 'Chennai' 'Kolkata'
#  'Chennai' 'Kolkata' 'Delhi' 'Chennai' 'Delhi' 'Kolkata' 'Chennai'
#  'Kolkata' 'Mumbai' 'Kolkata' 'Chennai' 'Mumbai' 'Mumbai']
# [0 1 0 0 1 1 1 0 1 1 0 0 1 0 1 1 0 0 1 0]

# %% [markdown]
# we can zip these to convert them to single list of tuples , each tuple in that list will correspond to a row in the dataframe

# %%
a=[3,4,5,10]
b=[6,7,8,10]
c=['a','b','c','d']
list(zip(a,b,c))
# Out:
# [(3, 6, 'a'), (4, 7, 'b'), (5, 8, 'c'), (10, 10, 'd')]

# %%
mydata=list(zip(age,city,default))

# %%
mydata
# Out:
# [(53, 'Delhi', 0),
#  (37, 'Mumbai', 1),
#  (78, 'Mumbai', 0),
#  (43, 'Kolkata', 0),
#  (54, 'Mumbai', 1),
#  (61, 'Chennai', 1),
#  (64, 'Kolkata', 1),
#  (71, 'Chennai', 0),
#  (24, 'Kolkata', 1),
#  (54, 'Delhi', 1),
#  (76, 'Chennai', 0),
#  (53, 'Delhi', 0),
#  (31, 'Kolkata', 1),
#  (31, 'Chennai', 0),
#  (58, 'Kolkata', 1),
#  (49, 'Mumbai', 1),
#  (71, 'Kolkata', 0),
#  (18, 'Chennai', 0),
#  (62, 'Mumbai', 1),
#  (59, 'Mumbai', 0)]

# %%
df=pd.DataFrame(data=mydata,columns=['age','city','default'])

# %%
df
# Out:
#     age     city  default
# 0    53    Delhi        0
# 1    37   Mumbai        1
# 2    78   Mumbai        0
# 3    43  Kolkata        0
# 4    54   Mumbai        1
# 5    61  Chennai        1
# 6    64  Kolkata        1
# 7    71  Chennai        0
# 8    24  Kolkata        1
# 9    54    Delhi        1
# 10   76  Chennai        0
# 11   53    Delhi        0
# 12   31  Kolkata        1
# 13   31  Chennai        0
# 14   58  Kolkata        1
# 15   49   Mumbai        1
# 16   71  Kolkata        0
# 17   18  Chennai        0
# 18   62   Mumbai        1
# 19   59   Mumbai        0

# %% [markdown]
# Another way is to put them in a dictionary , you will not need to supply column names separately in this case

# %%
df=pd.DataFrame({'age':age,'city':city,'default':default}) #passing a dictionary, where key=Column names, values = list.

# %%
df
# Out:
#     age     city  default
# 0    53    Delhi        0
# 1    37   Mumbai        1
# 2    78   Mumbai        0
# 3    43  Kolkata        0
# 4    54   Mumbai        1
# 5    61  Chennai        1
# 6    64  Kolkata        1
# 7    71  Chennai        0
# 8    24  Kolkata        1
# 9    54    Delhi        1
# 10   76  Chennai        0
# 11   53    Delhi        0
# 12   31  Kolkata        1
# 13   31  Chennai        0
# 14   58  Kolkata        1
# 15   49   Mumbai        1
# 16   71  Kolkata        0
# 17   18  Chennai        0
# 18   62   Mumbai        1
# 19   59   Mumbai        0

# %% [markdown]
# just the process of creating them is different , there is no difference in properties of end result

# %% [markdown]
# we can read data from external file very easily using function read_csv from pandas

# %%
# on mac : option+cmd+c : copies file as path
# on windows : shift+right click on your file , choose the option copy as path

# %%
#pd.read_csv(folder/file.extension)
pd.read_csv("C:\Users\Jayanti\Documents\Edvancer\Batch 1 - 6th May 2023\data\loans data.csv")
# Out:
#   File "<ipython-input-14-3564c5990d55>", line 2
#     pd.read_csv("C:\Users\Jayanti\Documents\Edvancer\Batch 1 - 6th May 2023\data\loans data.csv")
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#pd.read_csv(folder/file.extension)
pd.read_csv(r"C:\Users\Jayanti\Documents\Edvancer\Batch 1 - 6th May 2023\data\loans data.csv")
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 0      36 months  debt_consolidation               14.90%    SC
# 1      36 months  debt_consolidation               28.36%    TX
# 2      60 months  debt_consolidation               23.81%    CA
# 3      36 months  debt_consolidation               14.30%    KS
# 4      36 months         credit_card               18.78%    NJ
# ...          ...                 ...                  ...   ...
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 0          MORTGAGE         6541.67    735-739                14
# 1          MORTGAGE         4583.33    715-719                12
# 2          MORTGAGE        11500.00    690-694                14
# 3          MORTGAGE         3833.33    695-699                10
# 4              RENT         3195.00    695-699                11
# ...             ...             ...        ...               ...
# 2495       MORTGAGE         9250.00    705-709                15
# 2496            OWN         8903.25    740-744                18
# 2497       MORTGAGE         2166.67    680-684                 4
# 2498           RENT         3500.00    675-679                 8
# 2499           RENT         3875.00    670-674                 7
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 0                       14272                             2.0
# 1                       11140                             1.0
# 2                       21977                             1.0
# 3                        9346                             0.0
# 4                       14469                             0.0
# ...                       ...                             ...
# 2495                    45880                             1.0
# 2496                    18898                             1.0
# 2497                     4544                             0.0
# 2498                        .                             0.0
# 2499                     7589                             0.0
#
#      Employment.Length
# 0             < 1 year
# 1              2 years
# 2              2 years
# 3              5 years
# 4              9 years
# ...                ...
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
# 2498           5 years
# 2499         10+ years
#
# [2500 rows x 15 columns]

# %%
#pd.read_csv(folder/file.extension)
pd.read_csv("C:/Users/Jayanti/Documents/Edvancer/Batch 1 - 6th May 2023/data/loans data.csv")
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 0      36 months  debt_consolidation               14.90%    SC
# 1      36 months  debt_consolidation               28.36%    TX
# 2      60 months  debt_consolidation               23.81%    CA
# 3      36 months  debt_consolidation               14.30%    KS
# 4      36 months         credit_card               18.78%    NJ
# ...          ...                 ...                  ...   ...
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 0          MORTGAGE         6541.67    735-739                14
# 1          MORTGAGE         4583.33    715-719                12
# 2          MORTGAGE        11500.00    690-694                14
# 3          MORTGAGE         3833.33    695-699                10
# 4              RENT         3195.00    695-699                11
# ...             ...             ...        ...               ...
# 2495       MORTGAGE         9250.00    705-709                15
# 2496            OWN         8903.25    740-744                18
# 2497       MORTGAGE         2166.67    680-684                 4
# 2498           RENT         3500.00    675-679                 8
# 2499           RENT         3875.00    670-674                 7
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 0                       14272                             2.0
# 1                       11140                             1.0
# 2                       21977                             1.0
# 3                        9346                             0.0
# 4                       14469                             0.0
# ...                       ...                             ...
# 2495                    45880                             1.0
# 2496                    18898                             1.0
# 2497                     4544                             0.0
# 2498                        .                             0.0
# 2499                     7589                             0.0
#
#      Employment.Length
# 0             < 1 year
# 1              2 years
# 2              2 years
# 3              5 years
# 4              9 years
# ...                ...
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
# 2498           5 years
# 2499         10+ years
#
# [2500 rows x 15 columns]

# %%
file=r"C:\Users\Jayanti\Documents\Edvancer\Batch 1 - 6th May 2023\data\loans data.csv"

# %% [markdown]
# here r is added at the begning of the path to file to make it a raw string , so that its treated as path as is and any special oocurences are not interpreted as their special meaning by python. For example \n means newline , which will be ignored when we add r at the beginning of the string

# %%
ld=pd.read_csv(file)

# %% [markdown]
# to view first few obs of the data we can write

# %%
# how many columns are there in the data
# how many rows are there in the data
# what are the column names
# subset data on row and column by using indices 
# subset data on rows using condition
# subset data using column names : select columns or remove columns
# subset data on rows and columns at once 
# look at some summary information about the data

# %%
ld
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 0      36 months  debt_consolidation               14.90%    SC
# 1      36 months  debt_consolidation               28.36%    TX
# 2      60 months  debt_consolidation               23.81%    CA
# 3      36 months  debt_consolidation               14.30%    KS
# 4      36 months         credit_card               18.78%    NJ
# ...          ...                 ...                  ...   ...
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 0          MORTGAGE         6541.67    735-739                14
# 1          MORTGAGE         4583.33    715-719                12
# 2          MORTGAGE        11500.00    690-694                14
# 3          MORTGAGE         3833.33    695-699                10
# 4              RENT         3195.00    695-699                11
# ...             ...             ...        ...               ...
# 2495       MORTGAGE         9250.00    705-709                15
# 2496            OWN         8903.25    740-744                18
# 2497       MORTGAGE         2166.67    680-684                 4
# 2498           RENT         3500.00    675-679                 8
# 2499           RENT         3875.00    670-674                 7
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 0                       14272                             2.0
# 1                       11140                             1.0
# 2                       21977                             1.0
# 3                        9346                             0.0
# 4                       14469                             0.0
# ...                       ...                             ...
# 2495                    45880                             1.0
# 2496                    18898                             1.0
# 2497                     4544                             0.0
# 2498                        .                             0.0
# 2499                     7589                             0.0
#
#      Employment.Length
# 0             < 1 year
# 1              2 years
# 2              2 years
# 3              5 years
# 4              9 years
# ...                ...
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
# 2498           5 years
# 2499         10+ years
#
# [2500 rows x 15 columns]

# %%
ld.head(7)
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
# 5  62403.0             6000                       6000        15.31%
# 6  48808.0            10000                      10000         7.90%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
# 5   36 months               other               20.05%    CT            OWN
# 6   36 months  debt_consolidation               26.09%    MA           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 0         6541.67    735-739                14                    14272
# 1         4583.33    715-719                12                    11140
# 2        11500.00    690-694                14                    21977
# 3         3833.33    695-699                10                     9346
# 4         3195.00    695-699                11                    14469
# 5         4891.67    670-674                17                    10391
# 6         2916.67    720-724                10                    15957
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years
# 5                             2.0           3 years
# 6                             0.0         10+ years

# %% [markdown]
# to get column names we can look attribute column of the data`

# %%
ld.tail()
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
# 2498   36 months      major_purchase               16.66%    NJ
# 2499   36 months  debt_consolidation                6.76%    NY
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 2495       MORTGAGE         9250.00    705-709                15
# 2496            OWN         8903.25    740-744                18
# 2497       MORTGAGE         2166.67    680-684                 4
# 2498           RENT         3500.00    675-679                 8
# 2499           RENT         3875.00    670-674                 7
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 2495                    45880                             1.0
# 2496                    18898                             1.0
# 2497                     4544                             0.0
# 2498                        .                             0.0
# 2499                     7589                             0.0
#
#      Employment.Length
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
# 2498           5 years
# 2499         10+ years

# %%
ld.sample(5)
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 1729   7254.0             1000                       1000         7.88%
# 899    7953.0            16000                      16000        14.59%
# 1300  75831.0            19125                      19125        18.49%
# 2248  73203.0            12000                      12000        14.09%
# 1397   7816.0            20000                      19900        10.25%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 1729   36 months              moving               17.15%    NY
# 899    36 months  debt_consolidation                9.47%    CA
# 1300   60 months               other               29.10%    GA
# 2248   36 months  debt_consolidation               19.49%    CA
# 1397   36 months  debt_consolidation               17.51%    DE
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 1729           RENT         6000.00    715-719                11
# 899            RENT         5416.67    690-694                 9
# 1300           RENT         4166.67    700-704                14
# 2248           RENT         6166.67    675-679                13
# 1397       MORTGAGE         7833.33    760-764                14
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 1729                    23572                             1.0
# 899                     15518                             0.0
# 1300                    28108                             3.0
# 2248                     6499                             0.0
# 1397                    49898                             0.0
#
#      Employment.Length
# 1729           3 years
# 899          10+ years
# 1300           6 years
# 2248           6 years
# 1397           5 years

# %%
ld.shape
# Out:
# (2500, 15)

# %%
ld.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'State',
#        'Home.Ownership', 'Monthly.Income', 'FICO.Range', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')

# %% [markdown]
# to see type of these columns we can use attribute dtypes

# %%
ld.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 0         6541.67    735-739                14                    14272
# 1         4583.33    715-719                12                    11140
# 2        11500.00    690-694                14                    21977
# 3         3833.33    695-699                10                     9346
# 4         3195.00    695-699                11                    14469
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %%
ld.dtypes
# Out:
# ID                                float64
# Amount.Requested                   object
# Amount.Funded.By.Investors         object
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance           object
# Inquiries.in.the.Last.6.Months    float64
# Employment.Length                  object
# dtype: object

# %% [markdown]
# flost64 here correponds to numeric values and object corresponds to categorical columns

# %% [markdown]
# to know how many rows and columns are their in the data we can use attribute shape

# %%
ld.shape
# Out:
# (2500, 15)

# %%
ld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2499 non-null   float64
#  1   Amount.Requested                2499 non-null   object
#  2   Amount.Funded.By.Investors      2499 non-null   object
#  3   Interest.Rate                   2500 non-null   object
#  4   Loan.Length                     2499 non-null   object
#  5   Loan.Purpose                    2499 non-null   object
#  6   Debt.To.Income.Ratio            2499 non-null   object
#  7   State                           2499 non-null   object
#  8   Home.Ownership                  2499 non-null   object
#  9   Monthly.Income                  2497 non-null   float64
#  10  FICO.Range                      2500 non-null   object
#  11  Open.CREDIT.Lines               2496 non-null   object
#  12  Revolving.CREDIT.Balance        2497 non-null   object
#  13  Inquiries.in.the.Last.6.Months  2497 non-null   float64
#  14  Employment.Length               2422 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 293.1+ KB

# %% [markdown]
# this tells us that the data has 2500 rows/observations and 15 columns in it

# %% [markdown]
# now lets subset this data on the basis of row and column numbers , keep in mind that count start with 0 for both

# %%
ld.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 0         6541.67    735-739                14                    14272
# 1         4583.33    715-719                12                    11140
# 2        11500.00    690-694                14                    21977
# 3         3833.33    695-699                10                     9346
# 4         3195.00    695-699                11                    14469
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# 0                             2.0          < 1 year
# 1                             1.0           2 years
# 2                             1.0           2 years
# 3                             0.0           5 years
# 4                             0.0           9 years

# %%
ld1=ld.iloc[3:7,1:5]
ld1
# Out:
#   Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Length
# 3            10000                       9975         9.99%   36 months
# 4            12000                      12000        11.71%   36 months
# 5             6000                       6000        15.31%   36 months
# 6            10000                      10000         7.90%   36 months

# %% [markdown]
# iloc here correponds to subsetting by position , to understand this better lets try to further subset this data

# %%
ld1.iloc[2:4,1:3]
# Out:
#   Amount.Funded.By.Investors Interest.Rate
# 5                       6000        15.31%
# 6                      10000         7.90%

# %% [markdown]
# as you can see here the position is relative to current data , not the original one

# %% [markdown]
# Generally however we do not subset data by positions , we subset by either conditions or column names , if we are subsetting just on the basis of conditions or just column names we can directly pass those in square brackets

# %%
ld[(ld['Home.Ownership']=='MORTGAGE') | (ld['Monthly.Income']>5000)][['Home.Ownership','Monthly.Income']]
# Out:
#      Home.Ownership  Monthly.Income
# 0          MORTGAGE         6541.67
# 1          MORTGAGE         4583.33
# 2          MORTGAGE        11500.00
# 3          MORTGAGE         3833.33
# 7          MORTGAGE        13863.42
# ...             ...             ...
# 2493       MORTGAGE         7083.33
# 2494       MORTGAGE         6666.67
# 2495       MORTGAGE         9250.00
# 2496            OWN         8903.25
# 2497       MORTGAGE         2166.67
#
# [1631 rows x 2 columns]

# %%
ld[(ld['Home.Ownership']=='MORTGAGE') | (ld['Monthly.Income']>5000)]
# in pandas combining condition the words and , or do not work . use & ,|
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 7     22090.0            33500                      33450        17.14%
# ...       ...              ...                        ...           ...
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 0      36 months  debt_consolidation               14.90%    SC
# 1      36 months  debt_consolidation               28.36%    TX
# 2      60 months  debt_consolidation               23.81%    CA
# 3      36 months  debt_consolidation               14.30%    KS
# 7      60 months         credit_card               14.70%    LA
# ...          ...                 ...                  ...   ...
# 2493   60 months               other               12.10%    IL
# 2494   36 months  debt_consolidation               15.29%    WA
# 2495   60 months  debt_consolidation               19.23%    NY
# 2496   60 months    home_improvement               21.54%    MD
# 2497   36 months  debt_consolidation                4.89%    PA
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 0          MORTGAGE         6541.67    735-739                14
# 1          MORTGAGE         4583.33    715-719                12
# 2          MORTGAGE        11500.00    690-694                14
# 3          MORTGAGE         3833.33    695-699                10
# 7          MORTGAGE        13863.42    705-709                12
# ...             ...             ...        ...               ...
# 2493       MORTGAGE         7083.33    675-679                16
# 2494       MORTGAGE         6666.67    685-689                13
# 2495       MORTGAGE         9250.00    705-709                15
# 2496            OWN         8903.25    740-744                18
# 2497       MORTGAGE         2166.67    680-684                 4
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 0                       14272                             2.0
# 1                       11140                             1.0
# 2                       21977                             1.0
# 3                        9346                             0.0
# 7                       27874                             0.0
# ...                       ...                             ...
# 2493                    17969                             1.0
# 2494                    17521                             0.0
# 2495                    45880                             1.0
# 2496                    18898                             1.0
# 2497                     4544                             0.0
#
#      Employment.Length
# 0             < 1 year
# 1              2 years
# 2              2 years
# 3              5 years
# 7            10+ years
# ...                ...
# 2493         10+ years
# 2494           5 years
# 2495           8 years
# 2496         10+ years
# 2497         10+ years
#
# [1631 rows x 15 columns]

# %% [markdown]
# a single column name can be directly passed

# %%
ld['Home.Ownership']
# Out:
# 0       MORTGAGE
# 1       MORTGAGE
# 2       MORTGAGE
# 3       MORTGAGE
# 4           RENT
#           ...
# 2495    MORTGAGE
# 2496         OWN
# 2497    MORTGAGE
# 2498        RENT
# 2499        RENT
# Name: Home.Ownership, Length: 2500, dtype: object

# %%
ld[['Home.Ownership','Monthly.Income']]
# Out:
#      Home.Ownership  Monthly.Income
# 0          MORTGAGE         6541.67
# 1          MORTGAGE         4583.33
# 2          MORTGAGE        11500.00
# 3          MORTGAGE         3833.33
# 4              RENT         3195.00
# ...             ...             ...
# 2495       MORTGAGE         9250.00
# 2496            OWN         8903.25
# 2497       MORTGAGE         2166.67
# 2498           RENT         3500.00
# 2499           RENT         3875.00
#
# [2500 rows x 2 columns]

# %% [markdown]
# however mulitple column names need to be passed as a list

# %%
ld[['Home.Ownership','Monthly.Income']]
# Out:
#      Home.Ownership  Monthly.Income
# 0          MORTGAGE         6541.67
# 1          MORTGAGE         4583.33
# 2          MORTGAGE        11500.00
# 3          MORTGAGE         3833.33
# 4              RENT         3195.00
# ...             ...             ...
# 2495       MORTGAGE         9250.00
# 2496            OWN         8903.25
# 2497       MORTGAGE         2166.67
# 2498           RENT         3500.00
# 2499           RENT         3875.00
#
# [2500 rows x 2 columns]

# %% [markdown]
# when using both condition and column names we need to use .loc with dataframe name

# %%
ld.loc[(ld['Home.Ownership']=='MORTGAGE') & (ld['Monthly.Income']>5000),
       ['Home.Ownership','FICO.Range']]

# %% [markdown]
# do keep in mind that the accessed elements in these ways can also be modified by equating them to appropriate replacement to them

# %% [markdown]
# in order to negate a condition or drop rows on the basis of a conditon , we just need to add a ~ symbol in front of the condition

# %%
ld[~((ld['Home.Ownership']=='MORTGAGE') & (ld['Monthly.Income']>5000))]

# %% [markdown]
# in order to drop columns on the basis of names we can make use of the inbuilt drop function

# %%
# axis=0 : rows , axis=1 : columns

# %%
a=ld.drop(['Home.Ownership','Monthly.Income'],axis=1)

# %%
a

# %% [markdown]
# if you scroll through the output you will find that those columns are no more in the data, this however doesnt modify the original data , these columns are still present in the data

# %%
ld.columns

# %% [markdown]
# you can equate the output to original data name in order to change it , like this

# %%
ld=ld.drop(['Home.Ownership','Monthly.Income'],axis=1)

# %%
ld.columns

# %% [markdown]
# or you can make use of the inplace option in the drop function to change the data inplace

# %%
ld.drop(['Debt.To.Income.Ratio', 'State'],axis=1,inplace=True)

# %% [markdown]
# this changes the data inplace

# %%
ld.columns

# %% [markdown]
# notice that those columns are not there in the data inmore , one more thing that you need to be careful with here is that when using inplace=True option, function drop doesnt output anything so dont equate it to original data. if you do original data will end becoming a None type object

# %% [markdown]
# another way to delete a column is to use keyword del , the same one which we used in context of dictionary

# %%
del ld['Employment.Length']

# %%
ld.columns

# %% [markdown]
# We will stop our dicsusion on pandas dataframe in this video. In the next video , we will see how to add new columns , and modify existing columns in the data. We will also see how to check , count and impute missing value in the data. See you in the next video
